# %% [markdown]
# # Estimate CNN Models

# %%
#TODO:
#* Lets have forcnn be training and nocnn be validation. No need for separate test set. Hmmmm no., wont have all classes.
#*In prepping, may want to ensure balance within (a) train and (b) validation

# Functions up top, then parameters / for loop below (some stuff doesn't need to be repeated for the for loop)

# %% [markdown]
# Adapted from:
#
# https://codelabs.developers.google.com/codelabs/keras-flowers-transfer-learning#0
#
# https://colab.research.google.com/github/GoogleCloudPlatform/training-data-analyst/blob/master/courses/fast-and-lean-data-science/04_Keras_Flowers_transfer_learning_solution.ipynb#scrollTo=M3G-2aUBQJ-H

# %% [markdown]
# ## Setup

# %%
## Global params
SURVEY_NAME = 'DHS'
SATELLITE = 's2'

if SATELLITE == 's2':
    IMAGE_SIZE = [224, 224]
    NUM_GROUPS = 5

if SATELLITE == 'l8':
    IMAGE_SIZE = [167, 167]
    NUM_GROUPS = 3

EPOCHS = 10
BATCH_SIZE = 32 # 16
VALIDATION_SPLIT = 0.2

# %%
import os, sys, math
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import random
from skimage import exposure
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import tensorflow as tf
print("Tensorflow version " + tf.__version__)
AUTOTUNE = tf.data.AUTOTUNE

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model, Model
# Out:
# /Users/robmarty/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)
# /Users/robmarty/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %%
import tensorflow as tf

# %%
# Authenticate Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Authenticate Google Cloud
from google.colab import auth
auth.authenticate_user()

# %%
GOOGLEDRIVE_DIRECTORY = os.path.join('/content/gdrive/My Drive/World Bank/IEs/Pakistan Poverty Estimation')

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Utility Functions

# %%
# Get actual values function
# https://www.tensorflow.org/api_docs/python/tf/data/TFRecordDataset

#### NTL Group
def decode_fn_ntl_group(record_bytes):
    return tf.io.parse_single_example(
      # Data
      record_bytes,

      # Schema
      {"viirs_ntl_group": tf.io.FixedLenFeature([], dtype=tf.int64)}
    )

def extract_ntl_group(TF_FILES):
    actual_values = []
    for batch in tf.data.TFRecordDataset([TF_FILES]).map(decode_fn_ntl_group):
        value = batch['viirs_ntl_group'].numpy()
        actual_values.append(value)

    return actual_values

#### UID
def decode_fn_uid(record_bytes):
    return tf.io.parse_single_example(
      # Data
      record_bytes,

      # Schema
      {"uid": tf.io.FixedLenFeature([], dtype=tf.string)}
    )

def extract_uid(TF_FILES):
    actual_values = []
    for batch in tf.data.TFRecordDataset([TF_FILES]).map(decode_fn_uid):
        value = batch['uid'].numpy()
        actual_values.append(value)

    return actual_values

# %%
def dataset_to_numpy_util(dataset, N, process_image = True):
    dataset = dataset.batch(N)

    for images, labels in dataset:
        numpy_images = images.numpy()
        numpy_labels = labels.numpy()

    if process_image:
        p2, p98 = np.percentile(numpy_images, (2,98))
        numpy_images = exposure.rescale_intensity(numpy_images, in_range=(p2, p98)) 
    break;

    return numpy_images, numpy_labels

def display_one_image(image, title, subplot, red=False):
    plt.subplot(subplot)
    plt.axis('off')
    plt.imshow(image)
    plt.title(title, fontsize=16, color='red' if red else 'black')
    return subplot+1

def display_9_images_from_dataset(dataset):
    subplot=331
    plt.figure(figsize=(13,13))
    images, labels = dataset_to_numpy_util(dataset, 9)
    for i, image in enumerate(images):
        title = labels[i] # CLASSES[labels[i]]
        subplot = display_one_image(image, title, subplot)
    if i >= 8:
        break;
              
    #plt.tight_layout()
    plt.subplots_adjust(wspace=0.1, hspace=0.1)
    plt.show()

def display_training_curves(training, validation, title, subplot):
    if subplot%10==1: # set up the subplots on the first call
        plt.subplots(figsize=(10,10), facecolor='#F0F0F0')
        #plt.tight_layout()
    ax = plt.subplot(subplot)
    ax.set_facecolor('#F8F8F8')
    ax.plot(training)
    ax.plot(validation)
    ax.set_title('model '+ title)
    ax.set_ylabel(title)
    ax.set_xlabel('epoch')
    ax.legend(['train', 'valid.'])

# %%
## To extract uid & ntl_group
def dataset_to_numpy_util_single_val(dataset, N):
    dataset = dataset.batch(N)

    for val in dataset:
        val = val.numpy()
        break;

    return val

# %% [markdown]
# ### Functions for reading images and labels from TFRecords

# %%
def load_dataset(filenames, sat_var, exp_det):
  # read from TFRecords. For optimal performance, read from multiple
  # TFRecord files at once and set the option experimental_deterministic = False
  # to allow order-altering optimizations.

  #### Define read_tfrecord
  # Define here. Later map over this function, and not sure how to
  # enter sat_var into the mapping
    def read_tfrecord(example, sat_var = sat_var):
    features = {'viirs_ntl_group': tf.io.FixedLenFeature([], tf.int64),
                sat_var: tf.io.FixedLenFeature([], tf.string)}
    parsed_features = tf.io.parse_single_example(example, features)

    image = tf.io.decode_png(parsed_features[sat_var], dtype=tf.dtypes.uint16)
    image = image / 10000 # within 0 and 1

    if sat_var != 'b_rgb':
        image = tf.repeat(image, repeats = 3, axis=2)

    label = tf.one_hot(parsed_features["viirs_ntl_group"], NUM_GROUPS)

    return image, label

  #### load_dataset function
    option_no_order = tf.data.Options()
    option_no_order.experimental_deterministic = exp_det

    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTOTUNE)
    dataset = dataset.with_options(option_no_order)

    dataset = dataset.map(read_tfrecord, num_parallel_calls=AUTOTUNE)

    return dataset

# %%
def read_tfrecord_uid(example):
    features = {'uid': tf.io.FixedLenFeature([], tf.string)}

    parsed_features = tf.io.parse_single_example(example, features)

    return parsed_features['uid']

def load_dataset_uid(filenames, exp_det):
  # read from TFRecords. For optimal performance, read from multiple
  # TFRecord files at once and set the option experimental_deterministic = False
  # to allow order-altering optimizations.

    option_no_order = tf.data.Options()
    option_no_order.experimental_deterministic = exp_det

    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTOTUNE)
    dataset = dataset.with_options(option_no_order)
    dataset = dataset.map(read_tfrecord_uid, num_parallel_calls=AUTOTUNE)
    return dataset

# %%
def read_tfrecord_ntl_group(example):
    features = {'viirs_ntl_group': tf.io.FixedLenFeature([], tf.int64)}
    parsed_features = tf.io.parse_single_example(example, features)

    label = tf.one_hot(parsed_features["viirs_ntl_group"], NUM_GROUPS)

    return label

def load_dataset_ntl_group(filenames, exp_det):
  # read from TFRecords. For optimal performance, read from multiple
  # TFRecord files at once and set the option experimental_deterministic = False
  # to allow order-altering optimizations.

    option_no_order = tf.data.Options()
    option_no_order.experimental_deterministic = exp_det

    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTOTUNE)
    dataset = dataset.with_options(option_no_order)
    dataset = dataset.map(read_tfrecord_ntl_group, num_parallel_calls=AUTOTUNE)
    return dataset

# %% [markdown]
# ### Functions to create batched datasets

# %%
def get_batched_dataset(filenames, sat_var, exp_det, train=False):
    dataset = load_dataset(filenames, sat_var, exp_det = exp_det)
    dataset = dataset.cache() # This dataset fits in RAM
    if train:
        # Best practices for Keras:
        # Training dataset: repeat then batch
        # Evaluation dataset: do not repeat
        dataset = dataset.repeat()
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTOTUNE) # prefetch next batch while training (autotune prefetch buffer size)
  # should shuffle too but this dataset was well shuffled on disk already
    return dataset
  # source: Dataset performance guide: https://www.tensorflow.org/guide/performance/datasets

def get_batched_dataset_uid(filenames, exp_det, train=False):
    dataset = load_dataset_uid(filenames, exp_det = exp_det)
    dataset = dataset.cache() # This dataset fits in RAM
    if train:
        # Best practices for Keras:
        # Training dataset: repeat then batch
        # Evaluation dataset: do not repeat
        dataset = dataset.repeat()
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTOTUNE) # prefetch next batch while training (autotune prefetch buffer size)
  # should shuffle too but this dataset was well shuffled on disk already
    return dataset
  # source: Dataset performance guide: https://www.tensorflow.org/guide/performance/datasets

# %% [markdown]
# ## Load TFRecords and divide into train/test Set

# %%
GCS_PATTERN = 'gs://ieconnectpovest/cnn_' + SATELLITE + '/tfrecords/*.tfrecord'
all_filenames = tf.io.gfile.glob(GCS_PATTERN)
len(all_filenames)
# Out:
# 704

# %%
forcnn_filenames = [x for x in all_filenames if 'forcnn_' in x]

split = int(len(forcnn_filenames) * VALIDATION_SPLIT)
training_filenames = forcnn_filenames[split:]
validation_filenames = forcnn_filenames[:split]

# %%
#TOTAL_OBS = len(extract_uid(all_filenames))
#print(TOTAL_OBS)

TOTAL_OBS_VALIDATION = len(extract_uid(validation_filenames))
print(TOTAL_OBS_VALIDATION)

TOTAL_OBS_TRAINING = len(extract_uid(training_filenames))
print(TOTAL_OBS_TRAINING)
# Out:
# 7031
# 29404

# %%
validation_steps = TOTAL_OBS_VALIDATION // BATCH_SIZE
steps_per_epoch  = TOTAL_OBS_TRAINING   // BATCH_SIZE

# %% [markdown]
# ## Example Images

# %%
sat_var = "b_rgb"
display_9_images_from_dataset(load_dataset(training_filenames, sat_var, exp_det = False))
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# ## Run CNN

# %%
#sat_var = "b_rgb" # b_rgb, b_ndvi, b_bu
for sat_var in ['b_ndvi', 'b_bu']:

    print(sat_var + ' ----------------------------------------------------------')

    # 1. PREP AND RUN MODEL ========================================================

    # Instantiate the datasets -----------------------------------------------------
    training_dataset = get_batched_dataset(training_filenames, sat_var, exp_det = False, train=True)
    validation_dataset = get_batched_dataset(validation_filenames, sat_var, exp_det = False, train=False)

    validation_dataset_exdtT = get_batched_dataset(validation_filenames, sat_var, exp_det = True, train=False)
    all_dataset_exdtT = get_batched_dataset(all_filenames, sat_var, exp_det = True, train=False)

    # Output names -----------------------------------------------------------------
    # Paths for saving model, predictions (on test) and featurs (on training)
    name_suffix = SATELLITE + "_" + sat_var

    CNN_MODEL_PATH = os.path.join(GOOGLEDRIVE_DIRECTORY, 'Data', SURVEY_NAME, 'FinalData',
                                'cnn_models', 
                                'model_' + name_suffix + '.h5')

    PREDICTIONS_PATH = os.path.join(GOOGLEDRIVE_DIRECTORY, 'Data', SURVEY_NAME, 'FinalData',
                                  'cnn_predictions',
                                  'predictions_' + name_suffix + '.csv')

    FEATURES_PATH = os.path.join(GOOGLEDRIVE_DIRECTORY, 'Data', SURVEY_NAME, 'FinalData',
                                  'cnn_features',
                                  'features_' + name_suffix + '.csv')

    # Define model -----------------------------------------------------------------
    ### Setup Pre-Trained Network
    #pretrained_model = tf.keras.applications.MobileNetV2(input_shape=[*IMAGE_SIZE, 3], include_top=False)
    pretrained_model = tf.keras.applications.VGG16(weights='imagenet', include_top=False ,input_shape=[*IMAGE_SIZE, 3])
    #pretrained_model = tf.keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=[*IMAGE_SIZE, 3])
    #pretrained_model = tf.keras.applications.MobileNet(weights='imagenet', include_top=False, input_shape=[*IMAGE_SIZE, 3])
    pretrained_model.trainable = False

    ### Setup Model
    model = tf.keras.Sequential([
      pretrained_model,
      tf.keras.layers.Flatten(),
      #tf.keras.layers.Dropout(0.2),
      tf.keras.layers.Dense(4096, activation='relu', name = 'fc1'),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.Dense(NUM_GROUPS, activation='softmax')
    ])

    model.compile(
      optimizer='rmsprop', # adam
      loss = 'categorical_crossentropy',
      metrics=['accuracy']
    )

    model.summary()

    # Run model --------------------------------------------------------------------
    ### Setup Early Stopping
    # Use early stopping to help with overfitting
    monitor = 'val_accuracy'
    mode = 'max'
    es = EarlyStopping(monitor=monitor, mode=mode, patience=5, verbose=False)

    mc = ModelCheckpoint(CNN_MODEL_PATH, monitor=monitor, mode=mode, 
                        verbose=True, save_best_only=True)

    ### Fit Model
    history = model.fit(training_dataset, 
                      steps_per_epoch=steps_per_epoch, 
                      epochs=EPOCHS,
                      callbacks=[es, mc],
                      validation_data=validation_dataset, 
                      validation_steps=validation_steps)

    # Show history -----------------------------------------------------------------
    print(history.history.keys())
    display_training_curves(history.history['accuracy'], history.history['val_accuracy'], 'accuracy', 211)
    display_training_curves(history.history['loss'], history.history['val_loss'], 'loss', 212)

    # 2. EXTRACT FEATURES AND PREDICTIONS ==========================================

    ## Load model ------------------------------------------------------------------
    model = load_model(CNN_MODEL_PATH)

    ## Double check evaluation -----------------------------------------------------
    model.evaluate(validation_dataset_exdtT) 

    ## Grab features ---------------------------------------------------------------
    feature_extractor = Model(inputs=model.inputs,
                    outputs=model.get_layer(name='fc1').output,)

    features = feature_extractor.predict(all_dataset_exdtT)
    features_df = pd.DataFrame(features).add_prefix('cnn_feat_')

    features_df['uid'] = dataset_to_numpy_util_single_val(load_dataset_uid(all_filenames, exp_det = True),features_df.shape[0])

    features_df.to_csv(FEATURES_PATH, index=False)

    ## Grab predicted value --------------------------------------------------------
    predictions = model.predict(validation_dataset_exdtT)
    predictions = predictions.argmax(axis=-1)

    true_values = dataset_to_numpy_util_single_val(load_dataset_ntl_group(validation_filenames, exp_det = True),predictions.shape[0])
    true_values = true_values.argmax(axis=-1)

    pred_df = pd.DataFrame({'predictions':predictions, 'true_values':true_values})
    pred_df['uid'] = dataset_to_numpy_util_single_val(load_dataset_uid(validation_filenames, exp_det = True),predictions.shape[0])

    pred_df.to_csv(PREDICTIONS_PATH, index=False)

    # Check predicted values -------------------------------------------------------
    print("Check predicted values")
    print(np.mean(pred_df['predictions'] == pred_df['true_values']))
# Out:
# b_ndvi ----------------------------------------------------------
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense (Dense)               (None, 5)                 20485
#
# =================================================================
# Total params: 117,499,717
# Trainable params: 102,785,029
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/10
# 918/918 [==============================] - ETA: 0s - loss: 1.4539 - accuracy: 0.6557
# Epoch 00001: val_accuracy improved from -inf to 0.60916, saving model to /content/gdrive/My Drive/World Bank/IEs/Pakistan Poverty Estimation/Data/DHS/FinalData/cnn_models/model_s2_b_ndvi.h5
# 918/918 [==============================] - 606s 659ms/step - loss: 1.4539 - accuracy: 0.6557 - val_loss: 1.4030 - val_accuracy: 0.6092
# Epoch 2/10
# 918/918 [==============================] - ETA: 0s - loss: 0.7839 - accuracy: 0.7002
# Epoch 00002: val_accuracy did not improve from 0.60916
# 918/918 [==============================] - 535s 583ms/step - loss: 0.7839 - accuracy: 0.7002 - val_loss: 1.7869 - val_accuracy: 0.5888
# Epoch 3/10
# 918/918 [==============================] - ETA: 0s - loss: 0.7438 - accuracy: 0.7145
# Epoch 00003: val_accuracy did not improve from 0.60916
# 918/918 [==============================] - 535s 582ms/step - loss: 0.7438 - accuracy: 0.7145 - val_loss: 2.3214 - val_accuracy: 0.5381
# Epoch 4/10
# 918/918 [==============================] - ETA: 0s - loss: 0.7290 - accuracy: 0.7209
# Epoch 00004: val_accuracy did not improve from 0.60916
# 918/918 [==============================] - 533s 580ms/step - loss: 0.7290 - accuracy: 0.7209 - val_loss: 2.4668 - val_accuracy: 0.4762
# Epoch 5/10
# 918/918 [==============================] - ETA: 0s - loss: 0.7163 - accuracy: 0.7267
# Epoch 00005: val_accuracy did not improve from 0.60916
# 918/918 [==============================] - 535s 582ms/step - loss: 0.7163 - accuracy: 0.7267 - val_loss: 1.9194 - val_accuracy: 0.5295
# Epoch 6/10
# 918/918 [==============================] - ETA: 0s - loss: 0.7014 - accuracy: 0.7333
# Epoch 00006: val_accuracy did not improve from 0.60916
# 918/918 [==============================] - 535s 582ms/step - loss: 0.7014 - accuracy: 0.7333 - val_loss: 1.7289 - val_accuracy: 0.5803
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 220/220 [==============================] - 103s 449ms/step - loss: 1.3987 - accuracy: 0.6104
# Check predicted values
# 0.6104394822927037
# b_bu ----------------------------------------------------------
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_1 (Dense)             (None, 5)                 20485
#
# =================================================================
# Total params: 117,499,717
# Trainable params: 102,785,029
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/10
# 918/918 [==============================] - ETA: 0s - loss: 1.4802 - accuracy: 0.6735
# Epoch 00001: val_accuracy improved from -inf to 0.56093, saving model to /content/gdrive/My Drive/World Bank/IEs/Pakistan Poverty Estimation/Data/DHS/FinalData/cnn_models/model_s2_b_bu.h5
# 918/918 [==============================] - 622s 676ms/step - loss: 1.4802 - accuracy: 0.6735 - val_loss: 1.5064 - val_accuracy: 0.5609
# Epoch 2/10
# 918/918 [==============================] - ETA: 0s - loss: 0.8279 - accuracy: 0.7115
# Epoch 00002: val_accuracy did not improve from 0.56093
# 918/918 [==============================] - 539s 587ms/step - loss: 0.8279 - accuracy: 0.7115 - val_loss: 1.7240 - val_accuracy: 0.5595
# Epoch 3/10
# 918/918 [==============================] - ETA: 0s - loss: 0.7571 - accuracy: 0.7262
# Epoch 00003: val_accuracy did not improve from 0.56093
# 918/918 [==============================] - 539s 587ms/step - loss: 0.7571 - accuracy: 0.7262 - val_loss: 2.1559 - val_accuracy: 0.5024
# Epoch 4/10
# 918/918 [==============================] - ETA: 0s - loss: 0.7115 - accuracy: 0.7381
# Epoch 00004: val_accuracy did not improve from 0.56093
# 918/918 [==============================] - 538s 586ms/step - loss: 0.7115 - accuracy: 0.7381 - val_loss: 1.9921 - val_accuracy: 0.4866
# Epoch 5/10
# 918/918 [==============================] - ETA: 0s - loss: 0.6868 - accuracy: 0.7507
# Epoch 00005: val_accuracy did not improve from 0.56093
# 918/918 [==============================] - 539s 587ms/step - loss: 0.6868 - accuracy: 0.7507 - val_loss: 2.1346 - val_accuracy: 0.5287
# Epoch 6/10
# 918/918 [==============================] - ETA: 0s - loss: 0.6522 - accuracy: 0.7634
# Epoch 00006: val_accuracy did not improve from 0.56093
# 918/918 [==============================] - 540s 588ms/step - loss: 0.6522 - accuracy: 0.7634 - val_loss: 1.9767 - val_accuracy: 0.5188
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 220/220 [==============================] - 104s 456ms/step - loss: 1.5027 - accuracy: 0.5622
# Check predicted values
# 0.5622244346465652

# %% [markdown]
# ## Setup

# %%
# Out:
# Tensorflow version 2.7.0

# %%
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## TFRecords - Train/Test Set

# %%
# Out:
# 704

# %%
## Check number of records in each tfrecord
if False:
    def decode_fn_uid(record_bytes):
        return tf.io.parse_single_example(
            # Data
            record_bytes,

            # Schema
            {"uid": tf.io.FixedLenFeature([], dtype=tf.string)}
        )

    def extract_uid(TF_FILES):
        actual_values = []
        for batch in tf.data.TFRecordDataset([TF_FILES]).map(decode_fn_uid):
            value = batch['uid'].numpy()
            actual_values.append(value)

        return actual_values

    df_all = pd.DataFrame()

    for record_i in all_filenames:
            
        # Create the pandas DataFrame
        data = [[record_i, 
                  len(extract_uid(record_i))]]

        df_i = pd.DataFrame(data, columns = ['tfrecord', 'n_record'])

        # Append dataframe
        df_all = df_all.append(df_i, ignore_index = True)

    df_all.head()

# %%
## Check Balance

# %%
if False:
    pd.DataFrame(extract_ntl_group(forcnn_filenames), 
                      columns = ['value']).value_counts()

# %%
if False:
    pd.DataFrame(extract_ntl_group(training_filenames), 
                      columns = ['value']).value_counts()

# %%
if False:
    pd.DataFrame(extract_ntl_group(validation_filenames), 
                      columns = ['value']).value_counts()

# %%
# Out:
# 7031
# 29404

# %%
## Step sizes
#validation_steps = int(TOTAL_OBS // len(forcnn_filenames) * len(validation_filenames)) // BATCH_SIZE
#steps_per_epoch = int(TOTAL_OBS // len(forcnn_filenames) * len(training_filenames)) // BATCH_SIZE

# %%
len(forcnn_filenames)
# Out:
# 358

# %% [markdown]
# ## Read images and labels from TFRecords

# %% [markdown]
# ## Example Images

# %% [markdown]
# ## Training and validation datasets

# %% [markdown]
# ## Model

# %%
#a = dataset_to_numpy_util(training_dataset, 1)
#a[0].shape

# %%
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_3 (Flatten)         (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  dropout_3 (Dropout)         (None, 4096)              0
#
#  dense_3 (Dense)             (None, 5)                 20485
#
# =================================================================
# Total params: 117,499,717
# Trainable params: 102,785,029
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# Out:
# Epoch 1/10
# 918/918 [==============================] - ETA: 0s - loss: 1.5144 - accuracy: 0.6752
# Epoch 00001: val_accuracy improved from -inf to 0.55565, saving model to /content/gdrive/My Drive/World Bank/IEs/Pakistan Poverty Estimation/Data/DHS/FinalData/cnn_models/model_s2_b_bu.h5
# 918/918 [==============================] - 616s 670ms/step - loss: 1.5144 - accuracy: 0.6752 - val_loss: 1.4179 - val_accuracy: 0.5557
# Epoch 2/10
# 918/918 [==============================] - ETA: 0s - loss: 0.8004 - accuracy: 0.7145
# Epoch 00002: val_accuracy improved from 0.55565 to 0.57420, saving model to /content/gdrive/My Drive/World Bank/IEs/Pakistan Poverty Estimation/Data/DHS/FinalData/cnn_models/model_s2_b_bu.h5
# 918/918 [==============================] - 559s 609ms/step - loss: 0.8004 - accuracy: 0.7145 - val_loss: 1.5416 - val_accuracy: 0.5742
# Epoch 3/10
# 918/918 [==============================] - ETA: 0s - loss: 0.7374 - accuracy: 0.7293
# Epoch 00003: val_accuracy did not improve from 0.57420
# 918/918 [==============================] - 548s 597ms/step - loss: 0.7374 - accuracy: 0.7293 - val_loss: 2.0764 - val_accuracy: 0.5391
# Epoch 4/10
# 918/918 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.7426
# Epoch 00004: val_accuracy did not improve from 0.57420
# 918/918 [==============================] - 546s 595ms/step - loss: 0.7121 - accuracy: 0.7426 - val_loss: 3.1208 - val_accuracy: 0.4399
# Epoch 5/10
# 918/918 [==============================] - ETA: 0s - loss: 0.6765 - accuracy: 0.7577
# Epoch 00005: val_accuracy did not improve from 0.57420
# 918/918 [==============================] - 549s 598ms/step - loss: 0.6765 - accuracy: 0.7577 - val_loss: 1.8226 - val_accuracy: 0.5221
# Epoch 6/10
# 918/918 [==============================] - ETA: 0s - loss: 0.6339 - accuracy: 0.7672
# Epoch 00006: val_accuracy did not improve from 0.57420
# 918/918 [==============================] - 547s 596ms/step - loss: 0.6339 - accuracy: 0.7672 - val_loss: 1.9149 - val_accuracy: 0.5300
# Epoch 7/10
# 918/918 [==============================] - ETA: 0s - loss: 0.6171 - accuracy: 0.7786
# Epoch 00007: val_accuracy did not improve from 0.57420
# 918/918 [==============================] - 543s 591ms/step - loss: 0.6171 - accuracy: 0.7786 - val_loss: 1.7471 - val_accuracy: 0.5151

# %%
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ## Extract Features and Grab Predicted Values

# %%
# Out:
# 220/220 [==============================] - 108s 470ms/step - loss: 1.5367 - accuracy: 0.5756
# [1.5366657972335815, 0.5755937695503235]

# %%
# Out:
# 0.6142796188308918

# %%
pred_df.head(10)
# Out:
#    predictions  true_values                uid
# 0            0            1  b'AL201700000434'
# 1            0            1  b'AL201700000390'
# 2            0            1  b'AL201700000324'
# 3            0            1  b'AL201700000484'
# 4            0            1  b'AL201700000698'
# 5            0            1  b'AM201500000170'
# 6            3            1  b'AM201500000268'
# 7            3            1  b'AM201500000231'
# 8            3            1  b'AM201500000190'
# 9            0            1  b'AM201500000257'
