# %% [markdown]
# # Extract DTL Data to OPM
#
# Extracts numpy array of DTL around BISP coordinates and saves a pandas dataframe (pickled) of the UIDs corresponding to each numpy array. Processes data so that features can be extracted from the numpy array using the trained CNN model.
#
# __Use the conda_python3 kernel; works better for installing geopandas and rasterio__

# %% [markdown]
# ## Setup

# %%
# This takes a while
#%conda install geopandas
#%conda install rasterio
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/noarch::imageio==2.9.0=py_0
#   - conda-forge/linux-64::jupyter_server==1.4.1=py36h5fab9bb_0
#   - conda-forge/noarch::black==20.8b1=py_1
#   - conda-forge/linux-64::bokeh==2.2.3=py36h5fab9bb_0
#   - defaults/linux-64::_anaconda_depends==5.1.0=py36_2
#   - conda-forge/noarch::pyls-black==0.4.6=pyh9f0ad1d_0
#   - conda-forge/noarch::aiobotocore==1.2.1=pyhd8ed1ab_0
#   - conda-forge/noarch::pyls-spyder==0.3.2=pyhd8ed1ab_0
#   - conda-forge/linux-64::anyio==2.1.0=py36h5fab9bb_0
#   - conda-forge/noarch::jupyterlab_server==2.3.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::matplotlib-base==3.3.4=py36hd391965_0
#   - conda-forge/linux-64::spyder==4.2.0=py36h5fab9bb_0
#   - conda-forge/noarch::python-language-server==0.36.2=pyhd8ed1ab_0
#   - conda-forge/noarch::seaborn-base==0.11.1=pyhd8ed1ab_1
#   - conda-forge/noarch::sphinx==3.5.1=pyhd8ed1ab_0
#   - conda-forge/noarch::nbclassic==0.2.6=pyhd8ed1ab_0
#   - conda-forge/linux-64::yarl==1.6.3=py36h8f6f2f9_1
#   - conda-forge/linux-64::idna_ssl==1.1.0=py36h9f0ad1d_1001
#   - conda-forge/noarch::numpydoc==1.1.0=py_1
#   - conda-forge/linux-64::scikit-image==0.16.2=py36hb3f55d8_0
#   - conda-forge/noarch::seaborn==0.11.1=hd8ed1ab_1
#   - conda-forge/linux-64::jupyter==1.0.0=py36h5fab9bb_6
#   - conda-forge/noarch::odo==0.5.1=py_1
#   - conda-forge/linux-64::matplotlib==3.3.4=py36h5fab9bb_0
#   - conda-forge/linux-64::blaze==0.11.3=py36_0
#   - conda-forge/noarch::jupyterlab==3.0.9=pyhd8ed1ab_0
#   - conda-forge/noarch::dask==2021.2.0=pyhd8ed1ab_0
#   - conda-forge/noarch::anaconda-client==1.7.2=py_0
#   - conda-forge/noarch::anaconda-project==0.9.1=pyhd8ed1ab_0
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/noarch::imageio==2.9.0=py_0
#   - conda-forge/linux-64::jupyter_server==1.4.1=py36h5fab9bb_0
#   - conda-forge/noarch::black==20.8b1=py_1
#   - conda-forge/linux-64::bokeh==2.2.3=py36h5fab9bb_0
#   - defaults/linux-64::_anaconda_depends==5.1.0=py36_2
#   - conda-forge/noarch::pyls-black==0.4.6=pyh9f0ad1d_0
#   - conda-forge/noarch::aiobotocore==1.2.1=pyhd8ed1ab_0
#   - conda-forge/noarch::pyls-spyder==0.3.2=pyhd8ed1ab_0
#   - conda-forge/linux-64::anyio==2.1.0=py36h5fab9bb_0
#   - conda-forge/noarch::jupyterlab_server==2.3.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::matplotlib-base==3.3.4=py36hd391965_0
#   - conda-forge/linux-64::spyder==4.2.0=py36h5fab9bb_0
#   - conda-forge/noarch::python-language-server==0.36.2=pyhd8ed1ab_0
#   - conda-forge/noarch::seaborn-base==0.11.1=pyhd8ed1ab_1
#   - conda-forge/noarch::sphinx==3.5.1=pyhd8ed1ab_0
#   - conda-forge/noarch::nbclassic==0.2.6=pyhd8ed1ab_0
#   - conda-forge/linux-64::yarl==1.6.3=py36h8f6f2f9_1
#   - conda-forge/linux-64::idna_ssl==1.1.0=py36h9f0ad1d_1001
#   - conda-forge/noarch::numpydoc==1.1.0=py_1
#   - conda-forge/linux-64::scikit-image==0.16.2=py36hb3f55d8_0
#   - conda-forge/noarch::seaborn==0.11.1=hd8ed1ab_1
#   - conda-forge/linux-64::jupyter==1.0.0=py36h5fab9bb_6
#   - conda-forge/noarch::odo==0.5.1=py_1
#   - conda-forge/linux-64::matplotlib==3.3.4=py36h5fab9bb_0
#   - conda-forge/linux-64::blaze==0.11.3=py36_0
#   - conda-forge/noarch::jupyterlab==3.0.9=pyhd8ed1ab_0
#   - conda-forge/noarch::dask==2021.2.0=pyhd8ed1ab_0
#   - conda-forge/noarch::anaconda-client==1.7.2=py_0
#   - conda-forge/noarch::anaconda-project==0.9.1=pyhd8ed1ab_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.4
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/python3
#
#   added / updated specs:
#     - geopandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     astroid-2.5.6              |   py36h5fab9bb_0         300 KB  conda-forge
#     boost-cpp-1.74.0           |       hc6e9bd1_2        16.3 MB  conda-forge
#     botocore-1.19.52           |     pyhd8ed1ab_0         4.4 MB  conda-forge
#     cfitsio-3.470              |       hb418390_7         1.3 MB  conda-forge
#     click-plugins-1.1.1        |             py_0           9 KB  conda-forge
#     cligj-0.7.1                |     pyhd8ed1ab_0          10 KB  conda-forge
#     dataclasses-0.8            |     pyh787bdff_0          22 KB  conda-forge
#     docutils-0.17.1            |   py36h5fab9bb_0         762 KB  conda-forge
#     fiona-1.8.18               |   py36h783755f_1         1.1 MB  conda-forge
#     flask-cors-3.0.8           |             py_0          14 KB  conda-forge
#     freexl-1.0.6               |       h7f98852_0          48 KB  conda-forge
#     gdal-3.2.1                 |   py36h5adf297_8         1.5 MB  conda-forge
#     geopandas-0.9.0            |     pyhd8ed1ab_0         957 KB  conda-forge
#     geos-3.9.1                 |       h9c3ff4c_2         1.1 MB  conda-forge
#     geotiff-1.6.0              |       hcf90da6_5         296 KB  conda-forge
#     hdf4-4.2.13                |    h10796ff_1005         949 KB  conda-forge
#     json-c-0.15                |       h98cffda_0         274 KB  conda-forge
#     kealib-1.4.14              |       hcc255d8_2         186 KB  conda-forge
#     libdap4-3.20.6             |       hd7c4107_1        11.4 MB  conda-forge
#     libgdal-3.2.1              |       h6636813_8        13.3 MB  conda-forge
#     libkml-1.3.0               |    h02e6976_1012         590 KB  conda-forge
#     libnetcdf-4.7.4            |nompi_h56d31a8_107         1.3 MB  conda-forge
#     librttopo-1.1.0            |       h1185371_6         235 KB  conda-forge
#     libspatialite-5.0.1        |       h20cb978_4         4.4 MB  conda-forge
#     lxml-4.6.3                 |   py36h04a5ba7_0         1.5 MB  conda-forge
#     munch-2.5.0                |             py_0          12 KB  conda-forge
#     pillow-8.1.2               |   py36ha6010c0_1         691 KB  conda-forge
#     poppler-0.89.0             |       h2de54a5_5        15.6 MB  conda-forge
#     poppler-data-0.4.10        |                0         3.8 MB  conda-forge
#     postgresql-13.1            |       h6303168_1         5.3 MB  conda-forge
#     proj-8.0.0                 |       h277dcde_0         3.1 MB  conda-forge
#     pylint-2.7.2               |   py36h5fab9bb_0         466 KB  conda-forge
#     pyproj-3.0.1               |   py36h6e9aebd_1         479 KB  conda-forge
#     shapely-1.7.1              |   py36h93b233e_4         442 KB  conda-forge
#     tiledb-2.2.4               |       hb9a9e87_1         2.6 MB  conda-forge
#     tzcode-2021a               |       h7f98852_1          68 KB  conda-forge
#     xerces-c-3.2.3             |       h9d8b166_2         1.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        96.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   aiohttp            conda-forge/linux-64::aiohttp-3.7.4-py36h8f6f2f9_0
#   astroid            conda-forge/linux-64::astroid-2.5.6-py36h5fab9bb_0
#   boost-cpp          conda-forge/linux-64::boost-cpp-1.74.0-hc6e9bd1_2
#   botocore           conda-forge/noarch::botocore-1.19.52-pyhd8ed1ab_0
#   cfitsio            conda-forge/linux-64::cfitsio-3.470-hb418390_7
#   click-plugins      conda-forge/noarch::click-plugins-1.1.1-py_0
#   cligj              conda-forge/noarch::cligj-0.7.1-pyhd8ed1ab_0
#   colorama           conda-forge/noarch::colorama-0.4.4-pyh9f0ad1d_0
#   dataclasses        conda-forge/noarch::dataclasses-0.8-pyh787bdff_0
#   docutils           conda-forge/linux-64::docutils-0.17.1-py36h5fab9bb_0
#   fiona              conda-forge/linux-64::fiona-1.8.18-py36h783755f_1
#   flask-cors         conda-forge/noarch::flask-cors-3.0.8-py_0
#   freexl             conda-forge/linux-64::freexl-1.0.6-h7f98852_0
#   gdal               conda-forge/linux-64::gdal-3.2.1-py36h5adf297_8
#   geopandas          conda-forge/noarch::geopandas-0.9.0-pyhd8ed1ab_0
#   geos               conda-forge/linux-64::geos-3.9.1-h9c3ff4c_2
#   geotiff            conda-forge/linux-64::geotiff-1.6.0-hcf90da6_5
#   hdf4               conda-forge/linux-64::hdf4-4.2.13-h10796ff_1005
#   idna               conda-forge/noarch::idna-2.10-pyh9f0ad1d_0
#   json-c             conda-forge/linux-64::json-c-0.15-h98cffda_0
#   jupyter_console    conda-forge/linux-64::jupyter_console-5.2.0-py36_1
#   kealib             conda-forge/linux-64::kealib-1.4.14-hcc255d8_2
#   libdap4            conda-forge/linux-64::libdap4-3.20.6-hd7c4107_1
#   libgdal            conda-forge/linux-64::libgdal-3.2.1-h6636813_8
#   libkml             conda-forge/linux-64::libkml-1.3.0-h02e6976_1012
#   libnetcdf          conda-forge/linux-64::libnetcdf-4.7.4-nompi_h56d31a8_107
#   librttopo          conda-forge/linux-64::librttopo-1.1.0-h1185371_6
#   libspatialite      conda-forge/linux-64::libspatialite-5.0.1-h20cb978_4
#   lxml               conda-forge/linux-64::lxml-4.6.3-py36h04a5ba7_0
#   munch              conda-forge/noarch::munch-2.5.0-py_0
#   openjpeg           conda-forge/linux-64::openjpeg-2.4.0-hf7af979_0
#   pillow             conda-forge/linux-64::pillow-8.1.2-py36ha6010c0_1
#   poppler            conda-forge/linux-64::poppler-0.89.0-h2de54a5_5
#   poppler-data       conda-forge/noarch::poppler-data-0.4.10-0
#   postgresql         conda-forge/linux-64::postgresql-13.1-h6303168_1
#   proj               conda-forge/linux-64::proj-8.0.0-h277dcde_0
#   pylint             conda-forge/linux-64::pylint-2.7.2-py36h5fab9bb_0
#   pyproj             conda-forge/linux-64::pyproj-3.0.1-py36h6e9aebd_1
#   requests           conda-forge/noarch::requests-2.25.1-pyhd3deb0d_0
#   shapely            conda-forge/linux-64::shapely-1.7.1-py36h93b233e_4
#   tiledb             conda-forge/linux-64::tiledb-2.2.4-hb9a9e87_1
#   tzcode             conda-forge/linux-64::tzcode-2021a-h7f98852_1
#   urllib3            conda-forge/noarch::urllib3-1.26.4-pyhd8ed1ab_0
#   xerces-c           conda-forge/linux-64::xerces-c-3.2.3-h9d8b166_2
#
# The following packages will be UPDATED:
#
#   openssl                                 1.1.1j-h7f98852_0 --> 1.1.1k-h7f98852_0
#
#
#
# Downloading and Extracting Packages
# json-c-0.15          | 274 KB    | ##################################### | 100%
# libnetcdf-4.7.4      | 1.3 MB    | ##################################### | 100%
# boost-cpp-1.74.0     | 16.3 MB   | ##################################### | 100%
# astroid-2.5.6        | 300 KB    | ##################################### | 100%
# xerces-c-3.2.3       | 1.8 MB    | ##################################### | 100%
# docutils-0.17.1      | 762 KB    | ##################################### | 100%
# tzcode-2021a         | 68 KB     | ##################################### | 100%
# libspatialite-5.0.1  | 4.4 MB    | ##################################### | 100%
# geotiff-1.6.0        | 296 KB    | ##################################### | 100%
# geopandas-0.9.0      | 957 KB    | ##################################### | 100%
# dataclasses-0.8      | 22 KB     | ##################################### | 100%
# libgdal-3.2.1        | 13.3 MB   | ##################################### | 100%
# libdap4-3.20.6       | 11.4 MB   | ##################################### | 100%
# pillow-8.1.2         | 691 KB    | ##################################### | 100%
# shapely-1.7.1        | 442 KB    | ##################################### | 100%
# kealib-1.4.14        | 186 KB    | ##################################### | 100%
# munch-2.5.0          | 12 KB     | ##################################### | 100%
# pylint-2.7.2         | 466 KB    | ##################################### | 100%
# geos-3.9.1           | 1.1 MB    | ##################################### | 100%
# libkml-1.3.0         | 590 KB    | ##################################### | 100%
# poppler-0.89.0       | 15.6 MB   | ##################################### | 100%
# click-plugins-1.1.1  | 9 KB      | ##################################### | 100%
# librttopo-1.1.0      | 235 KB    | ##################################### | 100%
# pyproj-3.0.1         | 479 KB    | ##################################### | 100%
# freexl-1.0.6         | 48 KB     | ##################################### | 100%
# poppler-data-0.4.10  | 3.8 MB    | ##################################### | 100%
# hdf4-4.2.13          | 949 KB    | ##################################### | 100%
# cligj-0.7.1          | 10 KB     | ##################################### | 100%
# flask-cors-3.0.8     | 14 KB     | ##################################### | 100%
# lxml-4.6.3           | 1.5 MB    | ##################################### | 100%
# botocore-1.19.52     | 4.4 MB    | ##################################### | 100%
# cfitsio-3.470        | 1.3 MB    | ##################################### | 100%
# gdal-3.2.1           | 1.5 MB    | ##################################### | 100%
# tiledb-2.2.4         | 2.6 MB    | ##################################### | 100%
# proj-8.0.0           | 3.1 MB    | ##################################### | 100%
# postgresql-13.1      | 5.3 MB    | ##################################### | 100%
# fiona-1.8.18         | 1.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.4
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/python3
#
#   added / updated specs:
#     - rasterio
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     affine-2.3.0               |             py_0          16 KB  conda-forge
#     aiohttp-3.7.3              |   py36h8f6f2f9_2         629 KB  conda-forge
#     astroid-2.5                |   py36h5fab9bb_1         297 KB  conda-forge
#     gdal-3.2.1                 |   py36h5adf297_7         1.3 MB  conda-forge
#     geotiff-1.6.0              |       h2b14fbe_4         297 KB  conda-forge
#     libgdal-3.2.1              |       h38ff51b_7        13.2 MB  conda-forge
#     libspatialite-5.0.1        |       he52d314_3         4.4 MB  conda-forge
#     lxml-4.6.2                 |   py36h04a5ba7_1         1.5 MB  conda-forge
#     proj-7.2.0                 |       h277dcde_2         3.0 MB  conda-forge
#     pylint-2.6.0               |   py36h5fab9bb_1         452 KB  conda-forge
#     pyproj-3.0.1               |   py36h13f0598_0         477 KB  conda-forge
#     rasterio-1.2.3             |   py36h62a5fbb_0         8.3 MB  conda-forge
#     requests-2.13.0            |           py36_0         780 KB  conda-forge
#     snuggs-1.4.7               |             py_0           8 KB  conda-forge
#     urllib3-1.26.3             |     pyhd8ed1ab_0          99 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        34.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   affine             conda-forge/noarch::affine-2.3.0-py_0
#   rasterio           conda-forge/linux-64::rasterio-1.2.3-py36h62a5fbb_0
#   snuggs             conda-forge/noarch::snuggs-1.4.7-py_0
#
# The following packages will be UPDATED:
#
#   idna                                    2.10-pyh9f0ad1d_0 --> 3.1-pyhd3deb0d_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   requests           conda-forge/noarch::requests-2.25.1-p~ --> conda-forge/linux-64::requests-2.13.0-py36_0
#
# The following packages will be DOWNGRADED:
#
#   aiohttp                              3.7.4-py36h8f6f2f9_0 --> 3.7.3-py36h8f6f2f9_2
#   astroid                              2.5.6-py36h5fab9bb_0 --> 2.5-py36h5fab9bb_1
#   dataclasses                              0.8-pyh787bdff_0 --> 0.7-pyhe4b4509_6
#   docutils                            0.17.1-py36h5fab9bb_0 --> 0.16-py36h5fab9bb_3
#   gdal                                 3.2.1-py36h5adf297_8 --> 3.2.1-py36h5adf297_7
#   geotiff                                  1.6.0-hcf90da6_5 --> 1.6.0-h2b14fbe_4
#   libgdal                                  3.2.1-h6636813_8 --> 3.2.1-h38ff51b_7
#   libspatialite                            5.0.1-h20cb978_4 --> 5.0.1-he52d314_3
#   lxml                                 4.6.3-py36h04a5ba7_0 --> 4.6.2-py36h04a5ba7_1
#   pillow                               8.1.2-py36ha6010c0_1 --> 8.1.0-py36ha6010c0_2
#   proj                                     8.0.0-h277dcde_0 --> 7.2.0-h277dcde_2
#   pylint                               2.7.2-py36h5fab9bb_0 --> 2.6.0-py36h5fab9bb_1
#   pyproj                               3.0.1-py36h6e9aebd_1 --> 3.0.1-py36h13f0598_0
#   urllib3                               1.26.4-pyhd8ed1ab_0 --> 1.26.3-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
# libspatialite-5.0.1  | 4.4 MB    | ##################################### | 100%
# libgdal-3.2.1        | 13.2 MB   | ##################################### | 100%
# rasterio-1.2.3       | 8.3 MB    | ##################################### | 100%
# lxml-4.6.2           | 1.5 MB    | ##################################### | 100%
# affine-2.3.0         | 16 KB     | ##################################### | 100%
# aiohttp-3.7.3        | 629 KB    | ##################################### | 100%
# proj-7.2.0           | 3.0 MB    | ##################################### | 100%
# pyproj-3.0.1         | 477 KB    | ##################################### | 100%
# snuggs-1.4.7         | 8 KB      | ##################################### | 100%
# geotiff-1.6.0        | 297 KB    | ##################################### | 100%
# gdal-3.2.1           | 1.3 MB    | ##################################### | 100%
# requests-2.13.0      | 780 KB    | ##################################### | 100%
# urllib3-1.26.3       | 99 KB     | ##################################### | 100%
# astroid-2.5          | 297 KB    | ##################################### | 100%
# pylint-2.6.0         | 452 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, math, pickle, datetime, json
import numpy as np
import pandas as pd
import geopandas as gpd
import json
import rasterio
from rasterio.plot import show

from geopandas import GeoDataFrame
from shapely.geometry import Point

from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (BaggingClassifier, AdaBoostClassifier, 
                              GradientBoostingClassifier, RandomForestClassifier)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import (accuracy_score, precision_score, 
                             recall_score, classification_report)
#from keras.models import load_model

import warnings
import random
#import tensorflow as tf
warnings.filterwarnings('ignore')

import boto3
from sagemaker import get_execution_role
from s3fs.core import S3FileSystem 
s3 = S3FileSystem()
role = get_execution_role()

## User Defined
import config as cf
import feature_extraction as fe

bucket = 'worldbank-pakistan-data'
LOCAL_DIR = '/home/ec2-user/SageMaker/'

# %% [markdown]
# ## Functions

# %%
def pd_to_gdp(df, lat_name = 'latitude', lon_name = 'longitude'):
    '''
    Converts a pandas dataframe with lat and long variables into
    geopandas point data

    Input:  df - pandas dataframe
            lat_name - name of latitude variable in df
            lon_name - name of longitude variable in df
    Output: geopandas dataframe
    '''

    geometry = [Point(xy) for xy in zip(df[lon_name], df[lat_name])]
    df = df.drop([lon_name, lat_name], axis=1)
    gdf = GeoDataFrame(df, crs="EPSG:4326", geometry=geometry)

    return gdf

def extract_dtl_opm(bands_type, year, param_name):
    '''
    Function to extract daytime lights to OPM survey data locations. Creates two objects:
    
    Input: bands_type - Right now, just RBG
           year - Year of daytime imagery data
           param_name -  Name of CNN parameters to use 
    
    Outputs: (1) A numpy array with daytime imagery values
             (2) A pandas dataframe with uids of OPM data, in the same order as the daytime imagery values
    '''

    # 0. Load Bands
    if bands_type == "RGB":
        bands = ['4', '3', '2']

    # 1. Load Grid for DTL Tiles
    dtl_tiles = gpd.read_file(s3.open('{}/{}'.format(bucket, os.path.join('Country Grid', 'FinalData', 'pak_grid_200km.geojson'))))
    #dtl_tiles = gpd.read_file(os.path.join(cf.DROPBOX_DIRECTORY, 'Data', 'Country Grid', 'FinalData', 'pak_grid_200km.geojson'))
    dtl_tiles.rename(columns = {'id': 'tile_id'}, inplace=True)

    # 2. Prep BISP data
    # Load, convert to geopandas, extract dtl tile
    bisp_df = pd.read_csv(s3.open('{}/{}'.format(bucket, os.path.join('OPM', 'FinalData - PII', 'GPS_uid_crosswalk.csv'))), engine = 'python')
    #bisp_df = pd.read_csv(os.path.join(cf.SECURE_DATA_DIRECTORY, 'Data', 'BISP', 'FinalData - PII', 'GPS_uid_crosswalk.csv'), engine = 'python')
    bisp_gdf = pd_to_gdp(bisp_df)
    bisp_gdf = gpd.sjoin(bisp_gdf, dtl_tiles, how="inner", op='intersects').reset_index(drop=True)
    bisp_gdf['geometry'] = bisp_gdf.buffer(distance = 0.75/111.12).envelope
    
    # 3. Extract DTL to BISP Coordinates

    # Load CNN parameters 
    # Use this for paramers; just effects img_height and img_weidth
    PARAM_PATH_JSON = os.path.join('CNN', param_name, 'CNN_parameters.json')

    content_object = boto3.resource('s3').Object(bucket, PARAM_PATH_JSON)
    file_content = content_object.get()['Body'].read().decode('utf-8')
    cnn_param_dict = json.loads(file_content)
    
    #with open(PARAM_PATH_JSON, 'r') as fp:
    #    cnn_param_dict = json.load(fp)

    # Extract
    DTL, bisp_gdf_processed = fe.map_DTL_NTL(input_gdf = bisp_gdf, 
                                        directory = os.path.join('Landsat', 'l8', str(year)), 
                                        bands = bands, 
                                        img_height = cnn_param_dict['image_height'], 
                                        img_width = cnn_param_dict['image_width'],
                                        year = year)

    bisp_gdf_processed = bisp_gdf_processed[['uid']]

    # 4. Export
    np.save(os.path.join(LOCAL_DIR, 'bisp_dtl_bands' + bands_type + "_" + str(year) + '.npy'), DTL)
    bisp_gdf_processed.to_pickle(os.path.join(LOCAL_DIR, 'bisp_dtl_uids_bands' + bands_type + "_" + str(year) + '.pkl'))

    boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join('OPM', 'FinalData', 'Individual Datasets', 'bisp_dtl_bands' + bands_type + "_" + str(year) + '.npy')).upload_file(os.path.join(LOCAL_DIR, 'bisp_dtl_bands' + bands_type + "_" + str(year) + '.npy'))
    boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join('OPM', 'FinalData', 'Individual Datasets', 'bisp_dtl_uids_bands' + bands_type + "_" + str(year) + '.pkl')).upload_file(os.path.join(LOCAL_DIR, 'bisp_dtl_uids_bands' + bands_type + "_" + str(year) + '.pkl'))

# %% [markdown]
# ## Extract Daytime Imagery to OPM

# %%
extract_dtl_opm("RGB", 2014, "Nbands3_nNtlBins3_minNTLbinCount16861")
# Out:
# 0/5361
# 10/5361
# 20/5361
# 30/5361
# 40/5361
# 50/5361
# 60/5361
# 70/5361
# 80/5361
# 90/5361
# 100/5361
# 110/5361
# 120/5361
# 130/5361
# 140/5361
# 150/5361
# 160/5361
# 170/5361
# 180/5361
# 190/5361
# 200/5361
# 210/5361
# 220/5361
# 230/5361
# 240/5361
# 250/5361
# 260/5361
# 270/5361
# 280/5361
# 290/5361
# 300/5361
# 310/5361
# 320/5361
# 330/5361
# 340/5361
# 350/5361
# 360/5361
# 370/5361
# 380/5361
# 390/5361
# 400/5361
# 410/5361
# 420/5361
# 430/5361
# 440/5361
# 450/5361
# 460/5361
# 470/5361
# 480/5361
# 490/5361
# 500/5361
# 510/5361
# 520/5361
# 530/5361
# 540/5361
# 550/5361
# 560/5361
# 570/5361
# 580/5361
# 590/5361
# 600/5361
# 610/5361
# 620/5361
# 630/5361
# 640/5361
# 650/5361
# 660/5361
# 670/5361
# 680/5361
# 690/5361
# 700/5361
# 710/5361
# 720/5361
# 730/5361
# 740/5361
# 750/5361
# 760/5361
# 770/5361
# 780/5361
# 790/5361
# 800/5361
# 810/5361
# 820/5361
# 830/5361
# 840/5361
# 850/5361
# 860/5361
# 870/5361
# 880/5361
# 890/5361
# 900/5361
# 910/5361
# 920/5361
# 930/5361
# 940/5361
# 950/5361
# 960/5361
# 970/5361
# 980/5361
# 990/5361
# 1000/5361
# 1010/5361
# 1020/5361
# 1030/5361
# 1040/5361
# 1050/5361
# 1060/5361
# 1070/5361
# 1080/5361
# 1090/5361
# 1100/5361
# 1110/5361
# 1120/5361
# 1130/5361
# 1140/5361
# 1150/5361
# 1160/5361
# 1170/5361
# 1180/5361
# 1190/5361
# 1200/5361
# 1210/5361
# 1220/5361
# 1230/5361
# 1240/5361
# 1250/5361
# 1260/5361
# 1270/5361
# 1280/5361
# 1290/5361
# 1300/5361
# 1310/5361
# 1320/5361
# 1330/5361
# 1340/5361
# 1350/5361
# 1360/5361
# 1370/5361
# 1380/5361
# 1390/5361
# 1400/5361
# 1410/5361
# 1420/5361
# 1430/5361
# 1440/5361
# 1450/5361
# 1460/5361
# 1470/5361
# 1480/5361
# 1490/5361
# 1500/5361
# 1510/5361
# 1520/5361
# 1530/5361
# 1540/5361
# 1550/5361
# 1560/5361
# 1570/5361
# 1580/5361
# 1590/5361
# 1600/5361
# 1610/5361
# 1620/5361
# 1630/5361
# 1640/5361
# 1650/5361
# 1660/5361
# 1670/5361
# 1680/5361
# 1690/5361
# 1700/5361
# 1710/5361
# 1720/5361
# 1730/5361
# 1740/5361
# 1750/5361
# 1760/5361
# 1770/5361
# 1780/5361
# 1790/5361
# 1800/5361
# 1810/5361
# 1820/5361
# 1830/5361
# 1840/5361
# 1850/5361
# 1860/5361
# 1870/5361
# 1880/5361
# 1890/5361
# 1900/5361
# 1910/5361
# 1920/5361
# 1930/5361
# 1940/5361
# 1950/5361
# 1960/5361
# 1970/5361
# 1980/5361
# 1990/5361
# 2000/5361
# 2010/5361
# 2020/5361
# 2030/5361
# 2040/5361
# 2050/5361
# 2060/5361
# 2070/5361
# 2080/5361
# 2090/5361
# 2100/5361
# 2110/5361
# 2130/5361
# 2140/5361
# 2150/5361
# 2160/5361
# 2170/5361
# 2180/5361
# 2190/5361
# 2200/5361
# 2210/5361
# 2220/5361
# 2230/5361
# 2240/5361
# 2250/5361
# 2260/5361
# 2270/5361
# 2280/5361
# 2290/5361
# 2300/5361
# 2310/5361
# 2320/5361
# 2330/5361
# 2340/5361
# 2350/5361
# 2360/5361
# 2370/5361
# 2380/5361
# 2390/5361
# 2400/5361
# 2410/5361
# 2420/5361
# 2440/5361
# 4510/5361
# 4520/5361
# 4530/5361
# 4540/5361
# 4550/5361
# 4560/5361
# 4570/5361
# 4580/5361
# 4590/5361
# 4600/5361
# 4610/5361
# 4620/5361
# 4630/5361
# 4640/5361
# 4650/5361
# 4660/5361
# 4670/5361
# 4680/5361
# 4690/5361
# 4700/5361
# 4710/5361
# 4720/5361
# 4730/5361
# 4740/5361
# 4750/5361
# 4760/5361
# 4770/5361
# 4780/5361
# 4790/5361
# 4800/5361
# 4810/5361
# 4820/5361
# 4830/5361
# 4840/5361
# 4850/5361
# 4860/5361
# 4870/5361
# 4880/5361
# 4890/5361
# 4900/5361
# 4910/5361
# 4920/5361
# 4930/5361
# 4940/5361
# 4950/5361
# 4960/5361
# 4970/5361
# 4980/5361
# 4990/5361
# 5000/5361
# 5010/5361
# 5020/5361
# 5030/5361
# 5040/5361
# 5050/5361
# 5060/5361
# 5070/5361
# 5080/5361
# 5090/5361
# 5100/5361
# 5110/5361
# 5120/5361
# 5130/5361
# 5140/5361
# 5150/5361
# 5160/5361
# 5170/5361
# 5180/5361
# 5190/5361
# 5200/5361
# 5210/5361
# 5220/5361
# 5230/5361
# 5240/5361
# 5250/5361
# 5260/5361
# 5270/5361
# 5280/5361
# 5290/5361
# 5300/5361
# 5310/5361
# 5320/5361
# 5330/5361
# 5340/5361
# 5350/5361
# 5360/5361

# %%
#function for just 1 band at a time
def extract_dtl_opm_1band(bands, year, param_name):
    '''
    Function to extract daytime lights to OPM survey data locations. Creates two objects:
    
    Input: bands_type - Right now, just RBG
           year - Year of daytime imagery data
           param_name -  Name of CNN parameters to use 
    
    Outputs: (1) A numpy array with daytime imagery values
             (2) A pandas dataframe with uids of OPM data, in the same order as the daytime imagery values
    '''

  

    # 1. Load Grid for DTL Tiles
    dtl_tiles = gpd.read_file(s3.open('{}/{}'.format(bucket, os.path.join('Country Grid', 'FinalData', 'pak_grid_200km.geojson'))))
    #dtl_tiles = gpd.read_file(os.path.join(cf.DROPBOX_DIRECTORY, 'Data', 'Country Grid', 'FinalData', 'pak_grid_200km.geojson'))
    dtl_tiles.rename(columns = {'id': 'tile_id'}, inplace=True)

    # 2. Prep BISP data
    # Load, convert to geopandas, extract dtl tile
    bisp_df = pd.read_csv(s3.open('{}/{}'.format(bucket, os.path.join('OPM', 'FinalData - PII', 'GPS_uid_crosswalk.csv'))), engine = 'python')
    #bisp_df = pd.read_csv(os.path.join(cf.SECURE_DATA_DIRECTORY, 'Data', 'BISP', 'FinalData - PII', 'GPS_uid_crosswalk.csv'), engine = 'python')
    bisp_gdf = pd_to_gdp(bisp_df)
    bisp_gdf = gpd.sjoin(bisp_gdf, dtl_tiles, how="inner", op='intersects').reset_index(drop=True)
    bisp_gdf['geometry'] = bisp_gdf.buffer(distance = 0.75/111.12).envelope
    
    # 3. Extract DTL to BISP Coordinates

    # Load CNN parameters 
    # Use this for paramers; just effects img_height and img_weidth
    PARAM_PATH_JSON = os.path.join('CNN', param_name, 'CNN_parameters.json')

    content_object = boto3.resource('s3').Object(bucket, PARAM_PATH_JSON)
    file_content = content_object.get()['Body'].read().decode('utf-8')
    cnn_param_dict = json.loads(file_content)
    
    #with open(PARAM_PATH_JSON, 'r') as fp:
    #    cnn_param_dict = json.load(fp)

    # Extract
    DTL, bisp_gdf_processed = fe.map_DTL_NTL(input_gdf = bisp_gdf, 
                                        directory = os.path.join('Landsat', 'l8', str(year)), 
                                        bands = bands, 
                                        img_height = cnn_param_dict['image_height'], 
                                        img_width = cnn_param_dict['image_width'],
                                        year = year)

    bisp_gdf_processed = bisp_gdf_processed[['uid']]

    # 4. Export
    np.save(os.path.join(LOCAL_DIR, 'bisp_dtl_band' + str(bands[0]) + "_" + str(year) + '.npy'), DTL)
    bisp_gdf_processed.to_pickle(os.path.join(LOCAL_DIR, 'bisp_dtl_uids_band' + str(bands[0]) + "_" + str(year) + '.pkl'))

    boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join('OPM', 'FinalData', 'Individual Datasets', 'bisp_dtl_band' + str(bands[0]) + "_" + str(year) + '.npy')).upload_file(os.path.join(LOCAL_DIR, 'bisp_dtl_band' + str(bands[0]) + "_" + str(year) + '.npy'))
    boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join('OPM', 'FinalData', 'Individual Datasets', 'bisp_dtl_uids_band' + str(bands[0]) + "_" + str(year) + '.pkl')).upload_file(os.path.join(LOCAL_DIR, 'bisp_dtl_uids_band' + str(bands[0]) + "_" + str(year) + '.pkl'))

# %%
extract_dtl_opm_1band([1], 2014, "Band1_nNtlBins3_minNTLbinCount1861") #not as long as 01_prep_data for_cnn.ipynb
